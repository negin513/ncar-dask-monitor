# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from ncar_branding import *


date_columns = ['Job Start', 'Job End']                                                                                                                                                                                       
date_format = '%Y-%m-%dT%H:%M:%S'
                       
df= pd.read_csv('log.txt', na_values='-',parse_dates=date_columns, date_format=date_format)

df['YearMonth'] = df['Job End'].dt.to_period('M')
df['Elapsed (h)'] = df['Elapsed (h)'].replace('-', np.nan)

df= df.dropna()
print (len(df))
df = df[df['Req Mem (GB)']!= 0]
print (len(df))
#cpu_jobs = cpu_jobs.dropna()
# Out:
# 5867221
# 5854796

# %%
plt.rcParams['font.weight'] = 'bold'
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['xtick.major.width'] = 1.5
plt.rcParams['ytick.major.width'] = 1.5

# %%
df['Day of Week'] = df['Job Start'].dt.dayofweek
len(df)
# Out:
# 5854796

# %%
df = df[df['YearMonth'] >= '2024-01']
len(df)
# Out:
# 5854796

# %%
cpu_jobs = df

# %%
cpu_jobs["Unused Mem (GB)"] = ( 
    cpu_jobs["Req Mem (GB)"] - cpu_jobs["Used Mem(GB)"]
)   
cpu_jobs["Unused Mem (%)"] = ( 
    cpu_jobs["Unused Mem (GB)"] / cpu_jobs["Req Mem (GB)"] * 100.0   )

cpu_jobs["Used Mem (%)"] = ( 
    cpu_jobs["Used Mem(GB)"] / cpu_jobs["Req Mem (GB)"] * 100.0   )

# %%
cpu_jobs.describe()
# Out:
#               Nodes         NCPUs  Req Mem (GB)  Used Mem(GB)  \
# count  5.854796e+06  5.854796e+06  5.854796e+06  5.854796e+06
# mean   1.002964e+00  1.308605e+00  1.280588e+01  5.182881e+00
# min    1.000000e+00  1.000000e+00  2.000000e-01  0.000000e+00
# 25%    1.000000e+00  1.000000e+00  1.000000e+00  4.000000e-01
# 50%    1.000000e+00  1.000000e+00  1.000000e+01  6.000000e-01
# 75%    1.000000e+00  1.000000e+00  1.200000e+01  2.600000e+00
# max    3.600000e+01  6.400000e+02  4.400000e+03  8.404700e+03
# std    1.243042e-01  3.124866e+00  3.053815e+01  2.383056e+01
#
#                            Job Start                        Job End  \
# count                        5854796                        5854796
# mean   2024-05-28 15:11:57.399921664  2024-05-28 15:51:10.689018112
# min              2023-12-03 17:24:27            2024-01-01 00:00:29
# 25%              2024-04-18 11:56:09     2024-04-18 13:33:25.500000
# 50%              2024-05-28 15:06:39            2024-05-28 15:17:18
# 75%              2024-07-25 19:16:10  2024-07-25 21:18:27.249999872
# max              2024-09-13 10:22:07            2024-09-13 10:22:14
# std                              NaN                            NaN
#
#         Elapsed (h)  Walltime (h)  Waittime (h)   Avg CPU (%)   Exit Status  \
# count  5.854796e+06  5.854796e+06  5.854796e+06  5.854796e+06  5.854796e+06
# mean   6.466399e-01  4.405267e+00  1.453239e+02  6.013298e+01  1.703294e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00 -2.900000e+01
# 25%    1.000000e-02  8.000000e-02  0.000000e+00  3.700000e+01  0.000000e+00
# 50%    1.000000e-02  3.300000e-01  5.000000e-02  6.000000e+01  0.000000e+00
# 75%    5.000000e-02  2.000000e+00  7.200000e-01  9.000000e+01  0.000000e+00
# max    7.200500e+02  7.200000e+02  4.794203e+05  8.730000e+03  2.710000e+02
# std    9.445339e+00  3.565486e+01  8.286569e+03  3.047518e+01  6.464027e+01
#
#         Day of Week  Unused Mem (GB)  Unused Mem (%)  Used Mem (%)
# count  5.854796e+06     5.854796e+06    5.854796e+06  5.854796e+06
# mean   2.639266e+00     7.623001e+00    4.432304e+01  5.567696e+01
# min    0.000000e+00    -8.148700e+03   -7.139000e+04  0.000000e+00
# 25%    1.000000e+00     4.000000e-01    4.000000e+01  5.000000e+00
# 50%    3.000000e+00     2.000000e+00    7.000000e+01  3.000000e+01
# 75%    4.000000e+00     1.000000e+01    9.500000e+01  6.000000e+01
# max    6.000000e+00     4.317700e+03    1.000000e+02  7.149000e+04
# std    1.764170e+00     2.863888e+01    1.827701e+02  1.827701e+02

# %%
cpu_jobs.replace(-np.inf, np.nan, inplace=True)
cpu_jobs = cpu_jobs.dropna()
cpu_jobs
# Out:
#                      Job ID      User      Queue  Nodes  NCPUs  Req Mem (GB)  \
# 0        2389182.casper-pbs  davestep        rda      1      1           1.0
# 1        2389168.casper-pbs     che43        htc      1      1          25.0
# 2        2389166.casper-pbs     che43        htc      1      1          25.0
# 3        2389165.casper-pbs     che43        htc      1      1          25.0
# 4        2376316.casper-pbs   afoster  jhublogin      1      1           4.0
# ...                     ...       ...        ...    ...    ...           ...
# 5881759  9287601.casper-pbs     tcram        rda      1      1           1.0
# 5881760  9287598.casper-pbs    chifan        rda      1      1           1.0
# 5881761  9287597.casper-pbs    chifan        rda      1      1           1.0
# 5881762  9287595.casper-pbs     tcram        rda      1      1           1.0
# 5881763  9287594.casper-pbs    chifan        rda      1      1           1.0
#
#          Used Mem(GB)           Job Start             Job End  Elapsed (h)  \
# 0                 0.0 2024-09-13 10:22:07 2024-09-13 10:22:14         0.00
# 1                 0.0 2024-09-13 10:21:46 2024-09-13 10:21:59         0.00
# 2                 0.1 2024-09-13 10:21:43 2024-09-13 10:21:59         0.00
# 3                 0.1 2024-09-13 10:21:43 2024-09-13 10:21:58         0.00
# 4                 3.9 2024-09-11 17:02:59 2024-09-13 10:21:58        41.32
# ...               ...                 ...                 ...          ...
# 5881759           0.0 2024-01-01 00:00:27 2024-01-01 00:01:03         0.00
# 5881760           0.0 2024-01-01 00:00:24 2024-01-01 00:00:54         0.00
# 5881761           0.0 2024-01-01 00:00:22 2024-01-01 00:00:52         0.00
# 5881762           0.0 2024-01-01 00:00:14 2024-01-01 00:00:47         0.01
# 5881763           0.0 2024-01-01 00:00:13 2024-01-01 00:00:29         0.00
#
#          ...  Waittime (h)                Job Name Avg CPU (%)  \
# 0        ...           0.0                  dsrqst        67.0
# 1        ...           0.0  dask-worker-casper-dav         4.0
# 2        ...           0.0  dask-worker-casper-dav        12.0
# 3        ...           0.0  dask-worker-casper-dav        11.0
# 4        ...           0.0         cr-login-stable        46.0
# ...      ...           ...                     ...         ...
# 5881759  ...           0.0                  dsupdt        10.0
# 5881760  ...           0.0                  dsupdt         8.0
# 5881761  ...           0.0                  dsupdt         8.0
# 5881762  ...           0.0                  dsupdt        10.0
# 5881763  ...           0.0                  dsupdt        15.0
#
#                                Resources Exit Status  YearMonth Day of Week  \
# 0         1:ncpus=1:mem=1gb:ompthreads=1           0    2024-09           4
# 1        1:ncpus=1:mem=25GB:ompthreads=1         271    2024-09           4
# 2        1:ncpus=1:mem=25GB:ompthreads=1         271    2024-09           4
# 3        1:ncpus=1:mem=25GB:ompthreads=1         271    2024-09           4
# 4          1:ncpus=1:mem=4G:ompthreads=1         271    2024-09           2
# ...                                  ...         ...        ...         ...
# 5881759   1:ncpus=1:mem=1gb:ompthreads=1           0    2024-01           0
# 5881760   1:ncpus=1:mem=1gb:ompthreads=1           0    2024-01           0
# 5881761   1:ncpus=1:mem=1gb:ompthreads=1           0    2024-01           0
# 5881762   1:ncpus=1:mem=1gb:ompthreads=1           0    2024-01           0
# 5881763   1:ncpus=1:mem=1gb:ompthreads=1           0    2024-01           0
#
#          Unused Mem (GB)  Unused Mem (%)  Used Mem (%)
# 0                    1.0           100.0           0.0
# 1                   25.0           100.0           0.0
# 2                   24.9            99.6           0.4
# 3                   24.9            99.6           0.4
# 4                    0.1             2.5          97.5
# ...                  ...             ...           ...
# 5881759              1.0           100.0           0.0
# 5881760              1.0           100.0           0.0
# 5881761              1.0           100.0           0.0
# 5881762              1.0           100.0           0.0
# 5881763              1.0           100.0           0.0
#
# [5854796 rows x 21 columns]

# %%
jobs_per_month = cpu_jobs.groupby('YearMonth').size().reset_index(name='Count')
jobs_per_month.set_index('YearMonth', inplace=True)
jobs_per_month
# Out:
#              Count
# YearMonth
# 2024-01     299100
# 2024-02     546579
# 2024-03     392670
# 2024-04     630586
# 2024-05    1167975
# 2024-06     332109
# 2024-07    1838927
# 2024-08     483415
# 2024-09     163435

# %%
# Select all jobs where 'Unused Mem (GB)' is negative
negative_unused_mem_jobs = cpu_jobs[cpu_jobs['Used Mem (%)'] > 100.0]
negative_unused_mem_jobs
# Out:
#                            Job ID      User     Queue  Nodes  NCPUs  \
# 31       2386323[1982].casper-pbs    mingge       htc      1      1
# 37             2382814.casper-pbs   butlerz  largemem      1     36
# 53       2386323[1986].casper-pbs    mingge       htc      1      1
# 59             2388825.casper-pbs  rpconroy       rda      1      2
# 75             2388130.casper-pbs   mhayman       htc      1      1
# ...                           ...       ...       ...    ...    ...
# 5881750    9281172[23].casper-pbs  taereemk       htc      1      1
# 5881751     9281173[5].casper-pbs  taereemk       htc      1      1
# 5881753        9286998.casper-pbs    adixit       htc      1      4
# 5881754        9286989.casper-pbs    adixit       htc      1      4
# 5881755        9286996.casper-pbs    adixit       htc      1      4
#
#          Req Mem (GB)  Used Mem(GB)           Job Start             Job End  \
# 31              200.0         220.9 2024-09-13 06:30:06 2024-09-13 10:17:38
# 37              361.0         781.4 2024-09-12 10:15:03 2024-09-13 10:16:48
# 53              200.0         220.8 2024-09-13 07:20:53 2024-09-13 10:12:47
# 59                0.2           0.4 2024-09-13 10:09:17 2024-09-13 10:09:46
# 75               30.0          55.5 2024-09-13 08:17:17 2024-09-13 10:05:47
# ...               ...           ...                 ...                 ...
# 5881750          12.0          23.4 2023-12-31 09:15:36 2024-01-01 00:02:58
# 5881751          12.0          42.2 2023-12-31 12:23:37 2024-01-01 00:02:53
# 5881753          10.0          56.2 2023-12-31 15:07:05 2024-01-01 00:01:42
# 5881754          10.0          55.0 2023-12-31 15:05:07 2024-01-01 00:01:34
# 5881755          10.0          40.8 2023-12-31 15:06:32 2024-01-01 00:01:20
#
#          Elapsed (h)  ...  Waittime (h)       Job Name Avg CPU (%)  \
# 31              3.79  ...         15.13           C005        99.0
# 37             24.03  ...          0.00  compress_dirs        52.5
# 53              2.86  ...         15.98           C005        99.0
# 59              0.01  ...          0.00         dsrqst        32.0
# 75              1.81  ...          0.00     subproc_wv        99.0
# ...              ...  ...           ...            ...         ...
# 5881750        14.79  ...         47.61      nc_pr_m18        98.0
# 5881751        11.65  ...         50.74      nc_pr_m19        99.0
# 5881753         8.91  ...          0.00           copy        15.5
# 5881754         8.94  ...          0.00           copy        20.5
# 5881755         8.91  ...          0.00           copy        15.5
#
#                                              Resources Exit Status  YearMonth  \
# 31                    1:ncpus=1:mem=200GB:ompthreads=1           0    2024-09
# 37       1:ncpus=36:mpiprocs=36:mem=361GB:ompthreads=1         -29    2024-09
# 53                    1:ncpus=1:mem=200GB:ompthreads=1           0    2024-09
# 59                     1:ncpus=2:mem=200M:ompthreads=1           0    2024-09
# 75             1:ncpus=1:mem=30GB:ngpus=0:ompthreads=1           0    2024-09
# ...                                                ...         ...        ...
# 5881750                1:ncpus=1:mem=12GB:ompthreads=1           0    2024-01
# 5881751                1:ncpus=1:mem=12GB:ompthreads=1           0    2024-01
# 5881753              1:ncpus=4:mpiprocs=4:ompthreads=1           0    2024-01
# 5881754              1:ncpus=4:mpiprocs=4:ompthreads=1           0    2024-01
# 5881755              1:ncpus=4:mpiprocs=4:ompthreads=1           0    2024-01
#
#         Day of Week  Unused Mem (GB)  Unused Mem (%)  Used Mem (%)
# 31                4            -20.9      -10.450000    110.450000
# 37                3           -420.4     -116.454294    216.454294
# 53                4            -20.8      -10.400000    110.400000
# 59                4             -0.2     -100.000000    200.000000
# 75                4            -25.5      -85.000000    185.000000
# ...             ...              ...             ...           ...
# 5881750           6            -11.4      -95.000000    195.000000
# 5881751           6            -30.2     -251.666667    351.666667
# 5881753           6            -46.2     -462.000000    562.000000
# 5881754           6            -45.0     -450.000000    550.000000
# 5881755           6            -30.8     -308.000000    408.000000
#
# [433726 rows x 21 columns]

# %%
negative_jobs_per_month = negative_unused_mem_jobs.groupby('YearMonth').size().reset_index(name='Count')

# %%
grouped_stats = cpu_jobs.groupby('YearMonth')['Used Mem (%)'].agg(
    Min='min',
    Max='max',
    Mean='mean',
    Std= 'std',
    Q1=lambda x: x.quantile(0.25),
    Q3=lambda x: x.quantile(0.75)
).reset_index()

# Print the grouped statistics (optional)
print(grouped_stats)
# Out:
#   YearMonth  Min      Max       Mean         Std         Q1    Q3
# 0   2024-01  0.0  71490.0  59.632543  330.472251   3.200000  60.0
# 1   2024-02  0.0  22230.0  47.621922  191.108131   6.000000  60.0
# 2   2024-03  0.0  10775.0  66.391769  224.068911   2.000000  57.0
# 3   2024-04  0.0   9726.0  79.551298  255.956227   2.500000  43.0
# 4   2024-05  0.0   9718.0  36.112011  112.914851   4.000000  31.0
# 5   2024-06  0.0  11670.0  76.437440  208.615566   6.000000  75.0
# 6   2024-07  0.0   9690.0  57.151101  124.238338  40.000000  60.0
# 7   2024-08  0.0   8105.0  52.783313  200.932572   5.000000  40.0
# 8   2024-09  0.0   8510.0  47.123299  148.904724   2.214286  34.0

# %%
plt.figure(figsize=(12, 6))

# Plot Max, Mean, Q1, and Q3
#plt.plot(grouped_stats['YearMonth'].dt.to_timestamp(), grouped_stats['Max'], label='Max', marker='o')
plt.plot(grouped_stats['YearMonth'].dt.to_timestamp(), grouped_stats['Mean'], label='Mean', marker='o', color = ncar_lighter_blue)
#plt.plot(grouped_stats['YearMonth'].dt.to_timestamp(), grouped_stats['Q1'], label='Q1', marker='o')
#plt.plot(grouped_stats['YearMonth'].dt.to_timestamp(), grouped_stats['Q3'], label='Q3', marker='o')

plt.fill_between(grouped_stats['YearMonth'].dt.to_timestamp(),
                 grouped_stats['Mean'] - grouped_stats['Mean'],
                 grouped_stats['Mean'] + grouped_stats['Std'],
                 color=ncar_lightest_blue, alpha=0.2, label='Std Dev')

# Adding titles and labels
#plt.title('Max, Mean, Q1, and Q3 Over Time')
#plt.xlabel('YearMonth')
#plt.ylabel('Values')
plt.xlabel('Time')
plt.ylabel('Used Mem (%) \n (Used Mem - Req Mem)/Req Mem')
plt.xticks(rotation=45)
#plt.xlim(pd.to_datetime('2024-01'), pd.to_datetime('2024-09-15'))
plt.title("Average Memory Used by All Jobs on Casper")

# Adding a legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(12, 6))

# Plot Max, Mean, Q1, and Q3
plt.plot(grouped_stats['YearMonth'].dt.to_timestamp(), grouped_stats['Max'], label='Max', marker='o')
#plt.plot(grouped_stats['YearMonth'].dt.to_timestamp(), grouped_stats['Mean'], label='Mean', marker='o', color = 'blue')
#plt.plot(grouped_stats['YearMonth'].dt.to_timestamp(), grouped_stats['Q1'], label='Q1', marker='o')
#plt.plot(grouped_stats['YearMonth'].dt.to_timestamp(), grouped_stats['Q3'], label='Q3', marker='o')


# Adding titles and labels
#plt.title('Max, Mean, Q1, and Q3 Over Time')
#plt.xlabel('YearMonth')
#plt.ylabel('Values')
plt.xlabel('Time')
plt.ylabel('Used Mem (%) \n (Used Mem - Req Mem)/Req Mem')
plt.xticks(rotation=45)
#plt.xlim(pd.to_datetime('2023-12'), pd.to_datetime('2024-09-15'))

# Adding a legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a box plot using the original data, grouped by 'YearMonth'
plt.figure(figsize=(13, 7))
cpu_jobs.boxplot(column='Used Mem (%)',
                 by='YearMonth',
                 color = 'blue',
                 grid=False,
                 showfliers=False,
                 showmeans=True,
                 flierprops={'alpha':0.6, 
                                'markersize': 5,
                                'marker': '.'
                                },
                 meanprops={'marker': 'o',  # Circle marker for means
                            'markerfacecolor': 'orange', 
                            'markeredgecolor': 'orange',
                            'markersize': 5.5,
                           }
                )
                        
# Set y-axis to logarithmic scale
#plt.yscale('log')

# Set plot title and labels
plt.title('')
plt.suptitle('')  # Suppress the default title to keep the plot clean
plt.xticks(rotation=45)
plt.axhline(y=100, color='red', linestyle='--', linewidth=2, label='Threshold 100%')

plt.xlabel('Time')
plt.ylabel('Used Mem (%) \n (Used Mem - Req Mem)/Req Mem')
plt.tight_layout()

# Show plot
plt.show()

# %%
# Create a box plot using the original data, grouped by 'YearMonth'
plt.figure(figsize=(13, 7))
cpu_jobs.boxplot(column='Used Mem (%)',
                 by='YearMonth',
                 color = 'blue',
                 grid=False,
                 showfliers=True,
                 showmeans=True,
                 flierprops={'alpha':0.6, 
                                'markersize': 2,
                                'marker': 'x'
                                },
                 meanprops={'marker': 'o',  # Circle marker for means
                            'markerfacecolor': 'orange', 
                            'markeredgecolor': 'orange',
                            'markersize': 5.5,
                            'alpha':0.7 }
                )

# Set plot title and labels
#plt.title('Box Plot of Value by YearMonth')
plt.title ('')
plt.suptitle('')  # Suppress the default title to keep the plot clean
plt.xticks(rotation=45)
plt.axhline(y=100, color='red', linestyle='--', linewidth=2, label='Threshold 100%')

plt.xlabel('Time')
plt.ylabel('Used Mem (%) \n (Used Mem - Req Mem)/Req Mem')
plt.tight_layout()

plt.yscale('log')

# Show plot
plt.show()

# %%
negative_jobs_per_month
# Out:
#            Count
# YearMonth
# 2024-01    37471
# 2024-02    29861
# 2024-03    57339
# 2024-04    95175
# 2024-05    73010
# 2024-06    55917
# 2024-07    35174
# 2024-08    38124
# 2024-09    11655

# %%
def thousands_formatter(x, pos):
    return f'{int(x):,}'

plt.figure(figsize=(10, 6))
plt.plot(negative_jobs_per_month['YearMonth'].dt.to_timestamp(), negative_jobs_per_month['Count'], marker='o', linestyle='-', color='b')
plt.xlabel('Year-Month')
plt.ylabel('Jobs with > 100% Memory Usage')
plt.title('Number of Casper Jobs with >100% Memory Usage')
plt.xticks(rotation=45)
plt.grid(True)
plt.gca().yaxis.set_major_formatter(FuncFormatter(thousands_formatter))

plt.tight_layout()
plt.show()

# %%
def thousands_formatter(x, pos):
    return f'{int(x):,}'

plt.figure(figsize=(10, 6))
plt.plot(negative_jobs_per_month['YearMonth'].dt.to_timestamp(), negative_jobs_per_month['Count'], marker='o', linestyle='-', color='b')
plt.xlabel('Year-Month')
plt.ylabel('Jobs with > 100% Memory Usage')
plt.title('Number of Casper Jobs with >100% Memory Usage')
plt.xticks(rotation=45)
plt.grid(True)
plt.gca().yaxis.set_major_formatter(FuncFormatter(thousands_formatter))

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter


def thousands_formatter(x, pos):
    return f'{int(x):,}'

plt.figure(figsize=(10, 6))
plt.plot(negative_jobs_per_month['YearMonth'].dt.to_timestamp(), negative_jobs_per_month['Count'], marker='o', linestyle='-', color='b')
plt.xlabel('Year-Month')
plt.ylabel('Count')
plt.title('Number of Casper Jobs with >100% Memory Usage')
plt.xticks(rotation=45)
plt.grid(True)
plt.gca().yaxis.set_major_formatter(FuncFormatter(thousands_formatter))

plt.tight_layout()
plt.show()

# %%
negative_jobs_per_month.set_index('YearMonth', inplace=True)
result = negative_jobs_per_month['Count']/jobs_per_month['Count']*100
result
# Out:
# YearMonth
# 2024-01    12.527917
# 2024-02     5.463254
# 2024-03    14.602338
# 2024-04    15.093104
# 2024-05     6.250990
# 2024-06    16.836942
# 2024-07     1.912746
# 2024-08     7.886392
# 2024-09     7.131275
# Freq: M, Name: Count, dtype: float64

# %%
negative_jobs_per_month
# Out:
#            Count
# YearMonth
# 2024-01    37471
# 2024-02    29861
# 2024-03    57339
# 2024-04    95175
# 2024-05    73010
# 2024-06    55917
# 2024-07    35174
# 2024-08    38124
# 2024-09    11655

# %%
plt.figure(figsize=(10, 6))
filtered_df = result.loc['2023-11':]

filtered_df.plot(kind="bar", color='r')
plt.xlabel('Year-Month')
plt.ylabel('%Jobs with > 100% Memory Usage')
plt.title('% of Casper Jobs with >100% Memory Usage')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()#plt.bar(x, y2, bottomy1, color='b')

# %%
# users with negative memory: 
negative_unused_mem_jobs
user_counts = negative_unused_mem_jobs.groupby('YearMonth')['User'].nunique()
user_counts
# Out:
# YearMonth
# 2024-01    455
# 2024-02    526
# 2024-03    560
# 2024-04    532
# 2024-05    565
# 2024-06    566
# 2024-07    614
# 2024-08    604
# 2024-09    374
# Freq: M, Name: User, dtype: int64

# %%
# users with negative memory: 
negative_unused_mem_jobs
job_counts_per_user = negative_unused_mem_jobs.groupby(['YearMonth', 'User']).size()

top_users = job_counts_per_user.groupby('YearMonth').idxmax()
top_users

top_users_counts = job_counts_per_user.loc[top_users].reset_index(name='Number of Jobs')
top_users_counts.columns = ['YearMonth', 'User', 'Number of Jobs']
top_users_counts
# Out:
#   YearMonth      User  Number of Jobs
# 0   2024-01   mhayman            6747
# 1   2024-02  leihuang            6317
# 2   2024-03  leihuang           35575
# 3   2024-04  mcginnis           43273
# 4   2024-05     mwong           34118
# 5   2024-06  leihuang           32605
# 6   2024-07  mcginnis           10895
# 7   2024-08  rberrios           11780
# 8   2024-09   srahimi            3750

# %%
top_users_per_month = job_counts_per_user.groupby('YearMonth').nlargest(5).reset_index(level=0, drop=True)
pd.set_option('display.max_rows', None) 
print(top_users_per_month)
unraveled_df = top_users_per_month.reset_index(name='Job Count')
unraveled_df
# Out:
# YearMonth  User
# 2024-01    mhayman        6747
#            abrettin       6606
#            detouma        5361
#            davestep       2798
#            prein          1641
# 2024-02    leihuang       6317
#            detouma        3203
#            srahimi        2716
#            davestep       2626
#            mcginnis       2041
# 2024-03    leihuang      35575
#            detouma        3469
#            chifan         1497
#            rpconroy       1089
#            prein          1061
# 2024-04    mcginnis      43273
#            leihuang      32021
#            hakim          2286
#            jenorris       1470
#            chifan         1144
# 2024-05    mwong         34118
#            leihuang      20152
#            jenorris       2965
#            hartke         2573
#            rpconroy        933
# 2024-06    leihuang      32605
#            apinard        4505
#            mwong          2289
#            etsartsali     1653
#            olivarez       1099
# 2024-07    mcginnis      10895
#            gutmann        2277
#            antliya        1982
#            apinard        1684
#            tnicholas      1599
# 2024-08    rberrios      11780
#            ccummins       4328
#            anukesh        3301
#            mcginnis       1711
#            afoster        1529
# 2024-09    srahimi        3750
#            mhayman        1701
#            afoster        1220
#            mingge          463
#            frediani        335
# dtype: int64
#    YearMonth        User  Job Count
# 0    2024-01     mhayman       6747
# 1    2024-01    abrettin       6606
# 2    2024-01     detouma       5361
# 3    2024-01    davestep       2798
# 4    2024-01       prein       1641
# 5    2024-02    leihuang       6317
# 6    2024-02     detouma       3203
# 7    2024-02     srahimi       2716
# 8    2024-02    davestep       2626
# 9    2024-02    mcginnis       2041
# 10   2024-03    leihuang      35575
# 11   2024-03     detouma       3469
# 12   2024-03      chifan       1497
# 13   2024-03    rpconroy       1089
# 14   2024-03       prein       1061
# 15   2024-04    mcginnis      43273
# 16   2024-04    leihuang      32021
# 17   2024-04       hakim       2286
# 18   2024-04    jenorris       1470
# 19   2024-04      chifan       1144
# 20   2024-05       mwong      34118
# 21   2024-05    leihuang      20152
# 22   2024-05    jenorris       2965
# 23   2024-05      hartke       2573
# 24   2024-05    rpconroy        933
# 25   2024-06    leihuang      32605
# 26   2024-06     apinard       4505
# 27   2024-06       mwong       2289
# 28   2024-06  etsartsali       1653
# 29   2024-06    olivarez       1099
# 30   2024-07    mcginnis      10895
# 31   2024-07     gutmann       2277
# 32   2024-07     antliya       1982
# 33   2024-07     apinard       1684
# 34   2024-07   tnicholas       1599
# 35   2024-08    rberrios      11780
# 36   2024-08    ccummins       4328
# 37   2024-08     anukesh       3301
# 38   2024-08    mcginnis       1711
# 39   2024-08     afoster       1529
# 40   2024-09     srahimi       3750
# 41   2024-09     mhayman       1701
# 42   2024-09     afoster       1220
# 43   2024-09      mingge        463
# 44   2024-09    frediani        335

# %%
unraveled_df.plot(kind="bar")
# Out:
# <Axes: >

# %%
pivot_df = unraveled_df.pivot(index='User', columns='YearMonth', values='Job Count')
pivot_df
# Out:
# YearMonth   2024-01  2024-02  2024-03  2024-04  2024-05  2024-06  2024-07  \
# User
# abrettin     6606.0      NaN      NaN      NaN      NaN      NaN      NaN
# afoster         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# antliya         NaN      NaN      NaN      NaN      NaN      NaN   1982.0
# anukesh         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# apinard         NaN      NaN      NaN      NaN      NaN   4505.0   1684.0
# ccummins        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# chifan          NaN      NaN   1497.0   1144.0      NaN      NaN      NaN
# davestep     2798.0   2626.0      NaN      NaN      NaN      NaN      NaN
# detouma      5361.0   3203.0   3469.0      NaN      NaN      NaN      NaN
# etsartsali      NaN      NaN      NaN      NaN      NaN   1653.0      NaN
# frediani        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# gutmann         NaN      NaN      NaN      NaN      NaN      NaN   2277.0
# hakim           NaN      NaN      NaN   2286.0      NaN      NaN      NaN
# hartke          NaN      NaN      NaN      NaN   2573.0      NaN      NaN
# jenorris        NaN      NaN      NaN   1470.0   2965.0      NaN      NaN
# leihuang        NaN   6317.0  35575.0  32021.0  20152.0  32605.0      NaN
# mcginnis        NaN   2041.0      NaN  43273.0      NaN      NaN  10895.0
# mhayman      6747.0      NaN      NaN      NaN      NaN      NaN      NaN
# mingge          NaN      NaN      NaN      NaN      NaN      NaN      NaN
# mwong           NaN      NaN      NaN      NaN  34118.0   2289.0      NaN
# olivarez        NaN      NaN      NaN      NaN      NaN   1099.0      NaN
# prein        1641.0      NaN   1061.0      NaN      NaN      NaN      NaN
# rberrios        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# rpconroy        NaN      NaN   1089.0      NaN    933.0      NaN      NaN
# srahimi         NaN   2716.0      NaN      NaN      NaN      NaN      NaN
# tnicholas       NaN      NaN      NaN      NaN      NaN      NaN   1599.0
#
# YearMonth   2024-08  2024-09
# User
# abrettin        NaN      NaN
# afoster      1529.0   1220.0
# antliya         NaN      NaN
# anukesh      3301.0      NaN
# apinard         NaN      NaN
# ccummins     4328.0      NaN
# chifan          NaN      NaN
# davestep        NaN      NaN
# detouma         NaN      NaN
# etsartsali      NaN      NaN
# frediani        NaN    335.0
# gutmann         NaN      NaN
# hakim           NaN      NaN
# hartke          NaN      NaN
# jenorris        NaN      NaN
# leihuang        NaN      NaN
# mcginnis     1711.0      NaN
# mhayman         NaN   1701.0
# mingge          NaN    463.0
# mwong           NaN      NaN
# olivarez        NaN      NaN
# prein           NaN      NaN
# rberrios    11780.0      NaN
# rpconroy        NaN      NaN
# srahimi         NaN   3750.0
# tnicholas       NaN      NaN

# %%
# Create figure and axes
plot_data = top_users_per_month.reset_index().pivot(index='YearMonth', columns='User', values=0)
plot_data
# Out:
# User       abrettin  afoster  antliya  anukesh  apinard  ccummins  chifan  \
# YearMonth
# 2024-01      6606.0      NaN      NaN      NaN      NaN       NaN     NaN
# 2024-02         NaN      NaN      NaN      NaN      NaN       NaN     NaN
# 2024-03         NaN      NaN      NaN      NaN      NaN       NaN  1497.0
# 2024-04         NaN      NaN      NaN      NaN      NaN       NaN     NaN
# 2024-05         NaN      NaN      NaN      NaN      NaN       NaN     NaN
# 2024-06         NaN      NaN      NaN      NaN   4505.0       NaN     NaN
# 2024-07         NaN      NaN   1982.0      NaN      NaN       NaN     NaN
# 2024-08         NaN      NaN      NaN   3301.0      NaN    4328.0     NaN
# 2024-09         NaN   1220.0      NaN      NaN      NaN       NaN     NaN
#
# User       detouma  gutmann   hakim  jenorris  leihuang  mcginnis  mhayman  \
# YearMonth
# 2024-01     5361.0      NaN     NaN       NaN       NaN       NaN   6747.0
# 2024-02     3203.0      NaN     NaN       NaN    6317.0       NaN      NaN
# 2024-03     3469.0      NaN     NaN       NaN   35575.0       NaN      NaN
# 2024-04        NaN      NaN  2286.0       NaN   32021.0   43273.0      NaN
# 2024-05        NaN      NaN     NaN    2965.0   20152.0       NaN      NaN
# 2024-06        NaN      NaN     NaN       NaN   32605.0       NaN      NaN
# 2024-07        NaN   2277.0     NaN       NaN       NaN   10895.0      NaN
# 2024-08        NaN      NaN     NaN       NaN       NaN       NaN      NaN
# 2024-09        NaN      NaN     NaN       NaN       NaN       NaN   1701.0
#
# User         mwong  rberrios  srahimi
# YearMonth
# 2024-01        NaN       NaN      NaN
# 2024-02        NaN       NaN   2716.0
# 2024-03        NaN       NaN      NaN
# 2024-04        NaN       NaN      NaN
# 2024-05    34118.0       NaN      NaN
# 2024-06     2289.0       NaN      NaN
# 2024-07        NaN       NaN      NaN
# 2024-08        NaN   11780.0      NaN
# 2024-09        NaN       NaN   3750.0

# %%
# Plot data
plot_data.plot(kind='bar', stacked=False, figsize=(12, 8), colormap='tab20', width=1)
# Add titles and labels
plt.title('Top 10 Users by Jobs Exceeding 100% Memory Usage Per Month', fontsize=14)
plt.xlabel('Month and Year', fontsize=12)
plt.ylabel('Number of Jobs', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='User', bbox_to_anchor=(1.05, 1), loc='upper left',)
for container in ax.containers:
    for i, bar in enumerate(container):
        if bar.get_height() > 0:  # Only annotate bars with non-zero height
            ax.text(
                bar.get_x() + bar.get_width() / 2,  # X-coordinate (center of the bar)
                bar.get_y() + bar.get_height(),     # Y-coordinate (top of the bar)
                container.datavalues[i],            # The username
                ha='center', va='bottom', fontsize=10, rotation=90
            )

# Show plot
plt.tight_layout()
plt.show()

# %%
user_counts_all = cpu_jobs.groupby('YearMonth')['User'].nunique()
user_counts_all
# Out:
# YearMonth
# 2024-01    793
# 2024-02    916
# 2024-03    908
# 2024-04    924
# 2024-05    947
# 2024-06    957
# 2024-07    955
# 2024-08    976
# 2024-09    711
# Freq: M, Name: User, dtype: int64

# %%
# Plotting
plt.figure(figsize=(7, 5))
user_counts.plot(kind='bar', color=ncar_lightest_blue, edgecolor='black')
plt.title('Number of Users per Month with Jobs >100% Requested Memory')
plt.xlabel('')
plt.ylabel('Number of Users with Jobs >100% Requested Memory')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.savefig('users_per_month.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plotting
plt.figure(figsize=(10, 5))
user_counts_all.plot(kind='bar', color=ncar_lightest_blue, edgecolor='black')
plt.title('Unique Users per Month')
plt.xlabel('Month and Year')
plt.ylabel('Number of Unique Users')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Plotting
plt.figure(figsize=(7, 5))
negative_jobs_per_month['Count'].plot(kind='bar', color=ncar_lighter_blue, edgecolor='black')
plt.title('Number of Jobs per Month with >100% Requested Memory')
plt.xlabel('')
plt.ylabel('Jobs with >100% Requested Memory')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.gca().yaxis.set_major_formatter(FuncFormatter(thousands_formatter))

plt.savefig('jobs_per_month.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df = cpu_jobs

# %%
total_jobs_per_month = df.groupby('YearMonth').size()

# Filter jobs where 'Used Mem (%)' > 100
high_memory_jobs = df[df['Used Mem (%)'] > 100.0]
high_memory_jobs_per_month = high_memory_jobs.groupby('YearMonth').size()

# Prepare the DataFrame for plotting
plot_data = pd.DataFrame({
    'Total Jobs': total_jobs_per_month,
    'High Memory Usage Jobs': high_memory_jobs_per_month
})

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))
plot_data.plot(kind='bar', stacked=True, ax=ax,color=[ncar_blue, ncar_lightest_blue],edgecolor='black')
ax.set_title('Total Number of Jobs vs. High Memory Usage Jobs Per Month')
ax.set_xlabel('Month and Year')
ax.set_ylabel('Number of Jobs')
plt.xticks(rotation=45)
#plt.grid(True)
plt.show()

# %%
df['Job Start'] = pd.to_datetime(df['Job End'])
df['YearMonth'] = df['Job Start'].dt.to_period('M')

# Group by 'YearMonth' and count unique users
unique_users_per_month = df.groupby('YearMonth')['User'].nunique()

# Filter jobs where 'Used Mem (%)' > 100
high_memory_jobs = df[df['Used Mem (%)'] > 100.0]
unique_high_memory_users_per_month = high_memory_jobs.groupby('YearMonth')['User'].nunique()
unique_low_memory_users_per_month = unique_users_per_month - unique_high_memory_users_per_month
# Prepare the DataFrame for plotting
plot_data = pd.DataFrame({
    'Users with Jobs <100% Requested Memory': unique_low_memory_users_per_month,
    'Users with Jobs >100% Requested Memory': unique_high_memory_users_per_month
})

# Plotting
fig, ax = plt.subplots(figsize=(7, 5))
plot_data.plot(kind='bar', stacked=True, ax=ax,color=[ncar_blue, ncar_lightest_blue] , edgecolor='black')
ax.legend( bbox_to_anchor=(1.05, 1), loc='upper left')

ax.set_title('Total Unique Users vs. High Memory Usage Users Per Month')
ax.set_xlabel('')
ax.set_ylabel('Number of Users')
plt.xticks(rotation=45)
#plt.grid(True)
plt.show()

# %%
unique_low_memory_users_per_month = unique_users_per_month - unique_high_memory_users_per_month
unique_low_memory_users_per_month
# Out:
# YearMonth
# 2024-01    338
# 2024-02    390
# 2024-03    348
# 2024-04    392
# 2024-05    382
# 2024-06    391
# 2024-07    341
# 2024-08    372
# 2024-09    337
# Freq: M, Name: User, dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter


def thousands_formatter(x, pos):
    return f'{int(x):,}'

plt.figure(figsize=(10, 6))
plt.plot(negative_jobs_per_month['YearMonth'].dt.to_timestamp(), result, marker='o', linestyle='-', color='b')
plt.xlabel('Year-Month')
plt.ylabel('Count')
plt.title('Number of Casper Jobs with >100% Memory Usage')
plt.xticks(rotation=45)
plt.grid(True)
plt.gca().yaxis.set_major_formatter(FuncFormatter(thousands_formatter))

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YearMonth'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 9
#       6     return f'{int(x):,}'
#       8 plt.figure(figsize=(10, 6))
# ----> 9 plt.plot(negative_jobs_per_month['YearMonth'].dt.to_timestamp(), result, marker='o', linestyle='-', color='b')
#      10 plt.xlabel('Year-Month')
#      11 plt.ylabel('Count')
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'YearMonth'

# %%
negative_unused_mem_jobs.describe()
# Out:
#                Nodes          NCPUs   Req Mem (GB)   Used Mem(GB)  \
# count  268019.000000  268019.000000  268019.000000  268019.000000
# mean        1.004171       2.052071      10.965512      43.050803
# min         1.000000       1.000000       0.200000       0.500000
# 25%         1.000000       1.000000       3.000000      11.800000
# 50%         1.000000       1.000000      10.000000      24.900000
# 75%         1.000000       1.000000      10.000000      44.600000
# max        16.000000     256.000000     700.000000    8404.700000
# std         0.111789       6.153689      17.896271      70.001959
#
#                            Job Start                        Job End  \
# count                         268019                         268019
# mean   2024-03-21 04:32:54.869968384  2024-03-21 08:38:30.422260992
# min              2023-10-27 11:08:22            2023-10-27 11:20:28
# 25%              2023-12-28 22:30:12            2023-12-29 02:28:59
# 50%              2024-04-05 22:01:29            2024-04-05 22:09:53
# 75%              2024-05-22 02:26:11            2024-05-22 02:28:27
# max              2024-08-07 14:40:49            2024-08-07 15:04:18
# std                              NaN                            NaN
#
#          Elapsed (h)   Walltime (h)   Waittime (h)    Avg CPU (%)  \
# count  268019.000000  268019.000000  268019.000000  268019.000000
# mean        4.046919      17.140712    1346.779945      77.080832
# min         0.000000       0.020000       0.000000       0.000000
# 25%         0.070000       0.500000       0.000000      63.000000
# 50%         0.230000       6.000000       0.200000      86.000000
# 75%         1.060000      12.000000       2.250000      99.000000
# max       720.050000     720.000000  477015.030000    1534.000000
# std        31.781261      86.339328   25246.049556      25.944741
#
#          Exit Status  Unused Mem (GB)  Unused Mem (%)
# count  268019.000000    268019.000000   268019.000000
# mean       18.900888       -32.085291     -462.892747
# min       -29.000000     -8148.700000   -71390.000000
# 25%         0.000000       -31.200000     -480.000000
# 50%         0.000000       -15.700000     -220.000000
# 75%         0.000000        -9.900000     -166.250000
# max       271.000000        -0.300000     -100.100000
# std        67.076746        59.048384      692.939178

# %%
cpu_jobs['Unused Mem (%)'].plot()
# Out:
# <Axes: >

# %%
plt.hist(cpu_jobs['Unused Mem (%)'], bins=100, color='blue', edgecolor='black');

# %%
negative_unused_mem_jobs['Unused Mem (%)'].describe()
# Out:
# count    268019.000000
# mean       -462.892747
# std         692.939178
# min      -71390.000000
# 25%        -480.000000
# 50%        -220.000000
# 75%        -166.250000
# max        -100.100000
# Name: Unused Mem (%), dtype: float64
